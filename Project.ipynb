# %%
from openpyxl import Workbook
from openpyxl.chart import Linechart, Reference

Data = [
    ["Stock Price", "Month"],
    [150, "January"],
    [167, "February"],
    [175, "March"],
    [120, "April"],
    [140, "May"],
    [135, "June"],
    [160, "July"],
    [150, "August"],
    [173, "September"],
    [180, "October"],
    [168, "November"],
    [155, "December"]
]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 from openpyxl import Workbook
# ----> 2 from openpyxl.chart import Linechart, Reference
#       3 Data = [
#       4     ["Stock Price", "Month"],
#       5     [150, "January"],
#    (...)     16     [155, "December"]
#      17 ]
#
# ImportError: cannot import name 'Linechart' from 'openpyxl.chart' (/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/openpyxl/chart/__init__.py)
